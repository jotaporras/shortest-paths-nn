# %%
import torch

# %%
import numpy as np
B=4
srcs = torch.randn(B, 1)
tars = torch.randn(B, 1)
lengths = torch.randn(B, 1)


e1 = (srcs.numpy(),tars.numpy(),lengths.numpy())
e2 = (srcs.numpy(),tars.numpy(),lengths.numpy())

z = list(zip(e1,e2))

np.array([np.concatenate(x) for x in z]).squeeze().shape
# Out:
# (3, 8)

# %%
import pandas as pd 
pred_sample = pd.read_csv("../models/single_dataset/norway/res40/TAGConv/no-vn/siamese/p-4/mse_loss/tagconv-k3/1/new/preds.csv")

# %%
display(pred_sample.pred_maes.mean())
display(pred_sample.pred_nmaes.mean())
# Out:
# np.float64(0.2765130126992512)
# np.float64(0.03034500727699925)

# %%
pred_sample.pred_maes.hist()
# Out:
# <Axes: >
