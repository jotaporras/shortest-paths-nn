# %% [markdown]
# # e30 Cross-Terrain: Train on Philadelphia, Test on Norway
#
# This experiment trains models on Philadelphia terrain data at various resolutions and tests them on the Norway terrain test set. This measures cross-terrain generalization: can a model trained on one terrain accurately predict shortest paths on a completely different terrain?

# %%
import os
import re

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import wandb
import wandb_buddy as wb
from scipy.interpolate import griddata as sp_griddata
from tqdm import tqdm

# %%
ENTITY = "alelab"
PROJECT = "terrains"
TAG = "e30TR_cross_terrain_train_philly_test_norway"
E29_TAG = "e29TR_norway_hybrid_sampling_full_test"
ORIGINAL_DIM = 1000
SPATIAL_RES = 20

# %% [markdown]
# ## Helper functions

# %%
def extract_resolution(row):
    dataset_name = str(row["dataset_name"])
    res_match = re.search(r"res(\d+)", dataset_name)
    return int(res_match.group(1))


def get_metric_history_mean(entity, project, run_id, metric):
    api = wandb.Api()
    run = api.run(f"{entity}/{project}/{run_id}")
    history = run.history(keys=[metric], pandas=True)
    if history.empty or metric not in history.columns:
        return np.nan
    values = history[metric].dropna()
    return values.mean() if len(values) > 0 else np.nan


def add_metric_from_history(df, entity, project, source_metric, target_col):
    means = []
    for run_id in tqdm(df["id"], desc=f"Fetching {source_metric}"):
        means.append(get_metric_history_mean(entity, project, run_id, source_metric))
    df[target_col] = means
    return df

# %% [markdown]
# ---
# ## Load runs (e30 + e29)

# %%
print(f"Fetching runs with tag: {TAG}")
df = wb.load_runs(ENTITY, PROJECT, tags=[TAG])
print(f"Found {len(df)} runs")
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /home/teresa/.netrc.
# Fetching runs with tag: e30TR_cross_terrain_train_philly_test_norway
# Found 71 runs

# %%
if "resolution" not in df.columns:
    if "dataset_name" in df.columns:
        df["resolution"] = df.apply(extract_resolution, axis=1)
    else:
        df["resolution"] = df["name"].str.extract(r"res(\d+)", expand=False).astype(float)

if df["resolution"].dtype != int:
    df = df.dropna(subset=["resolution"]).copy()
    df["resolution"] = df["resolution"].astype(int)

df = df[df["resolution"] >= 3].copy()

df["density"] = 1 / (df["resolution"] ** 2)
df["num_nodes"] = df["resolution"].apply(
    lambda r: ((ORIGINAL_DIM - 1) // r + 1) ** 2
)
print(f"Resolutions: {sorted(df['resolution'].unique())}")
# Out:
# Resolutions: [np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20)]

# %%
print("Available columns:", df.columns.tolist())

if "layer_type" not in df.columns:
    df["layer_type"] = df["name"].str.extract(r"(TAGConv|SparseGT)", expand=False)
    print(f"Inferred layer_type from run name: {df['layer_type'].value_counts().to_dict()}")

api = wandb.Api()
embed_modes = {}
for _, row in tqdm(df[df["layer_type"] == "SparseGT"].iterrows(), desc="Fetching embedding_mode"):
    run = api.run(f"{ENTITY}/{PROJECT}/{row['id']}")
    embed_modes[row["id"]] = run.config.get("sparse_gt_embedding_mode", None)
df["sparse_gt_embedding_mode"] = df["id"].map(embed_modes)

def assign_model_label(row):
    if row["layer_type"] == "TAGConv":
        return "GNN"
    embed = row["sparse_gt_embedding_mode"]
    if embed == "random":
        return "SparseGT-Random"
    return "SparseGT-Data"

df["model_label"] = df.apply(assign_model_label, axis=1)

print(f"\nRuns with valid test_nmae: {df['test_nmae'].notna().sum()} / {len(df)}")
print(f"\nBy model_label:")
print(df.groupby("model_label")["test_nmae"].apply(lambda x: f"{x.notna().sum()}/{len(x)} valid"))
# Out:
# Available columns: ['name', 'id', 'state', 'created_at', 'heartbeat_at', 'tags', 'sweep_id', '_runtime', '_step', '_timestamp', '_wandb', 'best_val_nmae', 'epoch', 'final_train_acc_1pct', 'final_train_acc_2pct', 'final_train_acc_5pct', 'final_train_loss', 'final_train_mae', 'final_train_mse', 'final_train_nmae', 'global_step', 'p', 'test_acc_1pct', 'test_acc_2pct', 'test_acc_5pct', 'test_batch_loss', 'test_batch_mae', 'test_batch_mse', 'test_batch_nmae', 'test_loss', 'test_mae', 'test_mse', 'test_nmae', 'train_loss', 'train_mae', 'train_mse', 'train_nmae', 'val_acc_1pct', 'val_acc_2pct', 'val_acc_5pct', 'val_loss', 'val_mae', 'val_mse', 'val_nmae', 'resolution', 'density', 'num_nodes']
# Inferred layer_type from run name: {'SparseGT': 51, 'TAGConv': 18}
# Fetching embedding_mode: 51it [00:23,  2.17it/s]
# Runs with valid test_nmae: 69 / 69
#
# By model_label:
# model_label
# GNN                18/18 valid
# SparseGT-Data      18/18 valid
# SparseGT-Random    33/33 valid
# Name: test_nmae, dtype: object

# %%
print(f"Fetching e29 runs with tag: {E29_TAG}")
df_e29 = wb.load_runs(ENTITY, PROJECT, tags=[E29_TAG])
print(f"Found {len(df_e29)} e29 runs")

if "resolution" not in df_e29.columns:
    if "dataset_name" in df_e29.columns:
        df_e29["resolution"] = df_e29.apply(extract_resolution, axis=1)
    else:
        df_e29["resolution"] = df_e29["name"].str.extract(r"res(\d+)", expand=False).astype(float)

df_e29 = df_e29.dropna(subset=["resolution"]).copy()
df_e29["resolution"] = df_e29["resolution"].astype(int)
df_e29 = df_e29[df_e29["resolution"] >= 3].copy()
df_e29["num_nodes"] = df_e29["resolution"].apply(lambda r: ((ORIGINAL_DIM - 1) // r + 1) ** 2)

if "layer_type" not in df_e29.columns:
    df_e29["layer_type"] = df_e29["name"].str.extract(r"(TAGConv|SparseGT)", expand=False)

embed_modes_e29 = {}
for _, row in tqdm(df_e29[df_e29["layer_type"] == "SparseGT"].iterrows(), desc="Fetching e29 embedding_mode"):
    run = api.run(f"{ENTITY}/{PROJECT}/{row['id']}")
    embed_modes_e29[row["id"]] = run.config.get("sparse_gt_embedding_mode", None)
df_e29["sparse_gt_embedding_mode"] = df_e29["id"].map(embed_modes_e29)
df_e29["model_label"] = df_e29.apply(assign_model_label, axis=1)

print(f"\ne29 runs with valid test_nmae: {df_e29['test_nmae'].notna().sum()} / {len(df_e29)}")
print(df_e29.groupby("model_label")["test_nmae"].apply(lambda x: f"{x.notna().sum()}/{len(x)} valid"))
# Out:
# Fetching e29 runs with tag: e29TR_norway_hybrid_sampling_full_test
# Found 63 e29 runs
# Fetching e29 embedding_mode: 44it [00:17,  2.50it/s]
# e29 runs with valid test_nmae: 62 / 62
# model_label
# GNN                18/18 valid
# SparseGT-Data      18/18 valid
# SparseGT-Random    26/26 valid
# Name: test_nmae, dtype: object

# %% [markdown]
# ---
# ## Best performance per resolution & load predictions

# %%
df_valid_nmae = df.dropna(subset=["test_nmae"])
best_per_resolution_nmae = df_valid_nmae.loc[
    df_valid_nmae.groupby(["model_label", "resolution"])["test_nmae"].idxmin()
]
print(f"Best e30 runs per resolution (NMAE): {len(best_per_resolution_nmae)}")

df_e29_valid = df_e29.dropna(subset=["test_nmae"])
best_e29 = df_e29_valid.loc[
    df_e29_valid.groupby(["model_label", "resolution"])["test_nmae"].idxmin()
]
print(f"Best e29 runs per resolution (NMAE): {len(best_e29)}")
# Out:
# Best e30 runs per resolution (NMAE): 54
# Best e29 runs per resolution (NMAE): 53

# %%
cols = ["name", "model_label", "resolution", "num_nodes", "test_nmae", "state"]
display_cols = [c for c in cols if c in best_per_resolution_nmae.columns]
best_per_resolution_nmae.sort_values(["model_label", "resolution"])[display_cols]
# Out:
#                                    name      model_label  resolution  \
# 47   terrain-graph-TAGConv-res03-stage1              GNN           3
# 50   terrain-graph-TAGConv-res04-stage1              GNN           4
# 41   terrain-graph-TAGConv-res05-stage1              GNN           5
# 44   terrain-graph-TAGConv-res06-stage1              GNN           6
# 35   terrain-graph-TAGConv-res07-stage1              GNN           7
# 38   terrain-graph-TAGConv-res08-stage1              GNN           8
# 29   terrain-graph-TAGConv-res09-stage1              GNN           9
# 32   terrain-graph-TAGConv-res10-stage1              GNN          10
# 23   terrain-graph-TAGConv-res11-stage1              GNN          11
# 26   terrain-graph-TAGConv-res12-stage1              GNN          12
# 17   terrain-graph-TAGConv-res13-stage1              GNN          13
# 20   terrain-graph-TAGConv-res14-stage1              GNN          14
# 11   terrain-graph-TAGConv-res15-stage1              GNN          15
# 14   terrain-graph-TAGConv-res16-stage1              GNN          16
# 5    terrain-graph-TAGConv-res17-stage1              GNN          17
# 8    terrain-graph-TAGConv-res18-stage1              GNN          18
# 1    terrain-graph-TAGConv-res19-stage1              GNN          19
# 0    terrain-graph-TAGConv-res20-stage1              GNN          20
# 52  terrain-graph-SparseGT-res03-stage1    SparseGT-Data           3
# 54  terrain-graph-SparseGT-res04-stage1    SparseGT-Data           4
# 46  terrain-graph-SparseGT-res05-stage1    SparseGT-Data           5
# 49  terrain-graph-SparseGT-res06-stage1    SparseGT-Data           6
# 40  terrain-graph-SparseGT-res07-stage1    SparseGT-Data           7
# 43  terrain-graph-SparseGT-res08-stage1    SparseGT-Data           8
# 34  terrain-graph-SparseGT-res09-stage1    SparseGT-Data           9
# 37  terrain-graph-SparseGT-res10-stage1    SparseGT-Data          10
# 28  terrain-graph-SparseGT-res11-stage1    SparseGT-Data          11
# 31  terrain-graph-SparseGT-res12-stage1    SparseGT-Data          12
# 22  terrain-graph-SparseGT-res13-stage1    SparseGT-Data          13
# 25  terrain-graph-SparseGT-res14-stage1    SparseGT-Data          14
# 16  terrain-graph-SparseGT-res15-stage1    SparseGT-Data          15
# 19  terrain-graph-SparseGT-res16-stage1    SparseGT-Data          16
# 10  terrain-graph-SparseGT-res17-stage1    SparseGT-Data          17
# 13  terrain-graph-SparseGT-res18-stage1    SparseGT-Data          18
# 4   terrain-graph-SparseGT-res19-stage1    SparseGT-Data          19
# 6   terrain-graph-SparseGT-res20-stage1    SparseGT-Data          20
# 48  terrain-graph-SparseGT-res03-stage1  SparseGT-Random           3
# 51  terrain-graph-SparseGT-res04-stage1  SparseGT-Random           4
# 42  terrain-graph-SparseGT-res05-stage1  SparseGT-Random           5
# 45  terrain-graph-SparseGT-res06-stage1  SparseGT-Random           6
# 36  terrain-graph-SparseGT-res07-stage1  SparseGT-Random           7
# 69  terrain-graph-SparseGT-res08-stage1  SparseGT-Random           8
# 66  terrain-graph-SparseGT-res09-stage1  SparseGT-Random           9
# 67  terrain-graph-SparseGT-res10-stage1  SparseGT-Random          10
# 64  terrain-graph-SparseGT-res11-stage1  SparseGT-Random          11
# 27  terrain-graph-SparseGT-res12-stage1  SparseGT-Random          12
# 18  terrain-graph-SparseGT-res13-stage1  SparseGT-Random          13
# 21  terrain-graph-SparseGT-res14-stage1  SparseGT-Random          14
# 12  terrain-graph-SparseGT-res15-stage1  SparseGT-Random          15
# 15  terrain-graph-SparseGT-res16-stage1  SparseGT-Random          16
# 7   terrain-graph-SparseGT-res17-stage1  SparseGT-Random          17
# 59  terrain-graph-SparseGT-res18-stage1  SparseGT-Random          18
# 3   terrain-graph-SparseGT-res19-stage1  SparseGT-Random          19
# 56  terrain-graph-SparseGT-res20-stage1  SparseGT-Random          20
#
#     num_nodes  test_nmae     state
# 47     111556   0.047962  finished
# 50      62500   0.030283  finished
# 41      40000   0.036714  finished
# 44      27889   0.039525  finished
# 35      20449   0.037987  finished
# 38      15625   0.032735  finished
# 29      12544   0.042136  finished
# 32      10000   0.037222  finished
# 23       8281   0.032788  finished
# 26       7056   0.041742  finished
# 17       5929   0.032637  finished
# 20       5184   0.035515  finished
# 11       4489   0.032531  finished
# 14       3969   0.035339  finished
# 5        3481   0.032885  finished
# 8        3136   0.036075  finished
# 1        2809   0.034666  finished
# 0        2500   0.031480  finished
# 52     111556   0.038069  finished
# 54      62500   0.033681  finished
# 46      40000   0.048465  finished
# 49      27889   0.040113  finished
# 40      20449   0.040666  finished
# 43      15625   0.028123  finished
# 34      12544   0.032210  finished
# 37      10000   0.033184  finished
# 28       8281   0.041560  finished
# 31       7056   0.041648  finished
# 22       5929   0.042330  finished
# 25       5184   0.032769  finished
# 16       4489   0.033413  finished
# 19       3969   0.026002  finished
# 10       3481   0.034277  finished
# 13       3136   0.028503  finished
# 4        2809   0.037285  finished
# 6        2500   0.029098  finished
# 48     111556   0.057465  finished
# 51      62500   0.078966  finished
# 42      40000   0.048509  finished
# 45      27889   0.077772  finished
# 36      20449   0.045511  finished
# 69      15625   0.043342  finished
# 66      12544   0.050398  finished
# 67      10000   0.103766  finished
# 64       8281   0.064928  finished
# 27       7056   0.111603  finished
# 18       5929   0.091345  finished
# 21       5184   0.055914  finished
# 12       4489   0.068703  finished
# 15       3969   0.125704  finished
# 7        3481   0.095269  finished
# 59       3136   0.059003  finished
# 3        2809   0.058607  finished
# 56       2500   0.060431  finished

# %%
all_preds = []
for _, row in tqdm(best_per_resolution_nmae.iterrows(), desc="Loading predictions"):
    run = api.run(f"{ENTITY}/{PROJECT}/{row['id']}")
    log_dir = run.config.get("log_dir", None)
    if log_dir is None:
        continue
    preds_path = os.path.join(log_dir, "preds.csv")
    if not os.path.exists(preds_path):
        print(f"  Missing preds.csv for {row['name']} (res {row['resolution']})")
        continue
    preds_df = pd.read_csv(preds_path)
    preds_df["model_label"] = row["model_label"]
    preds_df["resolution"] = row["resolution"]
    preds_df["num_nodes"] = row["num_nodes"]
    all_preds.append(preds_df)

all_preds_df = pd.concat(all_preds, ignore_index=True)
all_preds_df = all_preds_df[all_preds_df["resolution"] >= 3]
print(f"Total predictions: {len(all_preds_df):,}")
print(f"Models: {sorted(all_preds_df['model_label'].unique())}")
print(f"Resolutions: {sorted(all_preds_df['resolution'].unique())}")
# Out:
# Loading predictions: 54it [00:09,  5.62it/s]
# Total predictions: 2,686,500
# Models: ['GNN', 'SparseGT-Data', 'SparseGT-Random']
# Resolutions: [np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20)]

# %%
spatial_runs = {}
for label in ["GNN", "SparseGT-Random", "SparseGT-Data"]:
    candidates = best_per_resolution_nmae[
        (best_per_resolution_nmae["model_label"] == label)
        & (best_per_resolution_nmae["resolution"] == SPATIAL_RES)
    ]
    if candidates.empty:
        print(f"  No run found for {label} at res {SPATIAL_RES}")
        continue
    row = candidates.sort_values("test_nmae").iloc[0]
    run_obj = api.run(f"{ENTITY}/{PROJECT}/{row['id']}")
    log_dir = run_obj.config.get("log_dir")
    test_data_path = run_obj.config.get("test_data")
    preds_path = os.path.join(log_dir, "preds.csv")
    if not os.path.exists(preds_path):
        print(f"  Missing preds.csv for {label}")
        continue
    preds_df = pd.read_csv(preds_path)
    spatial_runs[label] = {
        "preds": preds_df,
        "test_nmae": row["test_nmae"],
        "run_id": row["id"],
        "test_data_path": test_data_path,
    }
    print(f"  {label}: run={row['id']}, test_nmae={row['test_nmae']:.4f}, "
          f"preds={len(preds_df)}")

REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))

ref_label = list(spatial_runs.keys())[0]
test_npz_path = spatial_runs[ref_label]["test_data_path"]
if not os.path.isabs(test_npz_path):
    test_npz_path = os.path.join(REPO_ROOT, "data", test_npz_path)
print(f"\nLoading test graph from: {test_npz_path}")
test_data = np.load(test_npz_path, allow_pickle=True)
node_features = test_data["node_features"]
print(f"Test graph: {node_features.shape[0]} nodes, {node_features.shape[1]} features")

all_x = np.unique(node_features[:, 0])
all_y = np.unique(node_features[:, 1])
grid_x, grid_y = np.meshgrid(all_x, all_y)
grid_nx, grid_ny = len(all_x), len(all_y)

ref_preds = spatial_runs[ref_label]["preds"]
src_ids = np.unique(ref_preds["srcs"].astype(int).values)
src_coords = node_features[src_ids, :2]
src_order = np.lexsort((src_coords[:, 0], src_coords[:, 1]))
sorted_srcs = src_ids[src_order]
n_sources_to_plot = min(9, len(sorted_srcs))
positions = np.linspace(0, len(sorted_srcs) - 1, n_sources_to_plot, dtype=int)
sources_to_plot = sorted_srcs[positions]
print(f"Sources to plot: {sources_to_plot.tolist()}")
# Out:
#   GNN: run=6s300mxr, test_nmae=0.0315, preds=49750
#   SparseGT-Random: run=q7il8313, test_nmae=0.0604, preds=49750
#   SparseGT-Data: run=1ujuya3c, test_nmae=0.0291, preds=49750
#
# Loading test graph from: /home/teresa/shortest-paths-nn/data/generated2/full_test-004.npz
# Test graph: 250000 nodes, 3 features
# Sources to plot: [472, 18097, 41621, 81416, 119490, 134393, 174939, 204728, 247082]

# %% [markdown]
# ---
# ## Transferability plot (cross-terrain)

# %%
sns.set_theme(style="whitegrid", font_scale=1.2)

COLOR_MAP = {
    "GNN": "#1f77b4",
    "SparseGT-Random": "#ff7f0e",
    "SparseGT-Data": "#2ca02c",
}

fig, ax = plt.subplots(figsize=(10, 6))

for label in ["GNN", "SparseGT-Random", "SparseGT-Data"]:
    data = best_per_resolution_nmae[
        best_per_resolution_nmae["model_label"] == label
    ].sort_values("num_nodes")

    if data.empty:
        continue

    ax.plot(
        data["num_nodes"], data["test_nmae"],
        marker="o", label=label, color=COLOR_MAP[label],
        linewidth=1.5, markersize=5,
    )

ax.set_xscale("log")
ax.set_xlabel("Graph Size (n)")
ax.set_ylabel("Test NMAE (relative error)")
ax.set_title("Cross-terrain transferability: Train Philadelphia \u2192 Test Norway")
ax.legend(loc="upper right")
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid", font_scale=1.2)

MODEL_LABELS = ["GNN", "SparseGT-Random", "SparseGT-Data"]
COLOR_E30 = {"GNN": "#1f77b4", "SparseGT-Random": "#ff7f0e", "SparseGT-Data": "#2ca02c"}
COLOR_E29 = {"GNN": "#aec7e8", "SparseGT-Random": "#ffbb78", "SparseGT-Data": "#98df8a"}

fig, axes = plt.subplots(1, 3, figsize=(20, 6), sharey=True)

for ax, label in zip(axes, MODEL_LABELS):
    data_e30 = best_per_resolution_nmae[
        best_per_resolution_nmae["model_label"] == label
    ].sort_values("num_nodes")
    data_e29 = best_e29[
        best_e29["model_label"] == label
    ].sort_values("num_nodes")

    if not data_e29.empty:
        ax.plot(
            data_e29["num_nodes"], data_e29["test_nmae"],
            marker="s", label=f"Train on Norway", color=COLOR_E29[label],
            linewidth=2, markersize=5, linestyle="--",
        )
    if not data_e30.empty:
        ax.plot(
            data_e30["num_nodes"], data_e30["test_nmae"],
            marker="o", label=f"Train on Philly", color=COLOR_E30[label],
            linewidth=2, markersize=5,
        )

    ax.set_xscale("log")
    ax.set_xlabel("Graph Size (n)")
    ax.set_title(label)
    ax.legend(loc="upper right")
    ax.grid(True, alpha=0.3)

axes[0].set_ylabel("Test NMAE (relative error)")
fig.suptitle("Test on Norway: Train on Philly vs Train on Norway", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## NMAE per distance group

# %%
n_bins = 10
all_preds_df["distance_bin"] = pd.cut(all_preds_df["lengths"], bins=n_bins)
all_preds_df["abs_error"] = (all_preds_df["preds"] - all_preds_df["lengths"]).abs()
all_preds_df["nmae"] = all_preds_df["abs_error"] / all_preds_df["lengths"].clip(lower=1e-9)

nmae_by_group = (
    all_preds_df.groupby(["model_label", "resolution", "distance_bin"])
    .agg(mean_nmae=("nmae", "mean"), count=("nmae", "size"))
    .reset_index()
)

def format_interval(iv):
    left = max(iv.left, 0.0)
    return f"({left:.1f}, {iv.right:.1f}]"

MODEL_ORDER = ["GNN", "SparseGT-Random", "SparseGT-Data"]
all_resolutions = sorted(all_preds_df["resolution"].unique())

sns.set_theme(style="white", font_scale=1.0)
fig, axes = plt.subplots(
    1, 3, figsize=(22, 8), sharey=True,
    gridspec_kw={"width_ratios": [1, 1, 1]},
)

vmin = nmae_by_group["mean_nmae"].min()
vmax = nmae_by_group["mean_nmae"].quantile(0.95)

for ax_idx, model in enumerate(MODEL_ORDER):
    sub = nmae_by_group[nmae_by_group["model_label"] == model].copy()
    if sub.empty:
        axes[ax_idx].set_title(f"{model} (no data)")
        continue
    sub["bin_label"] = sub["distance_bin"].apply(format_interval)
    pivot = sub.pivot_table(index="bin_label", columns="resolution", values="mean_nmae")
    pivot = pivot.reindex(
        index=[format_interval(b) for b in sorted(sub["distance_bin"].unique())]
    )

    sns.heatmap(
        pivot, ax=axes[ax_idx], cmap="YlOrRd",
        vmin=vmin, vmax=vmax, annot=False,
        cbar=False,
    )
    axes[ax_idx].set_title(model, fontsize=13, fontweight="bold")
    axes[ax_idx].set_xlabel("Resolution", fontsize=11)
    if ax_idx == 0:
        axes[ax_idx].set_ylabel("True Distance Bin", fontsize=11)
    else:
        axes[ax_idx].set_ylabel("")

fig.subplots_adjust(right=0.92)
cbar_ax = fig.add_axes([0.93, 0.15, 0.015, 0.7])
sm = plt.cm.ScalarMappable(cmap="YlOrRd", norm=plt.Normalize(vmin=vmin, vmax=vmax))
fig.colorbar(sm, cax=cbar_ax, label="Mean NMAE")

fig.suptitle("Cross-terrain NMAE by distance group: Train Philly \u2192 Test Norway", fontsize=14, y=1.02)
plt.tight_layout(rect=[0, 0, 0.92, 1])
plt.show()
# Out:
# /tmp/ipykernel_3078135/2923604727.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   all_preds_df.groupby(["model_label", "resolution", "distance_bin"])
# /tmp/ipykernel_3078135/2923604727.py:31: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = sub.pivot_table(index="bin_label", columns="resolution", values="mean_nmae")
# /tmp/ipykernel_3078135/2923604727.py:31: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = sub.pivot_table(index="bin_label", columns="resolution", values="mean_nmae")
# /tmp/ipykernel_3078135/2923604727.py:31: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = sub.pivot_table(index="bin_label", columns="resolution", values="mean_nmae")

# %% [markdown]
# ---
# ## Spatial error maps

# %%
def build_nmae_maps(preds_df, sources, node_feats, gx, gy):
    pdf = preds_df.copy()
    pdf["srcs"] = pdf["srcs"].astype(int)
    pdf["tars"] = pdf["tars"].astype(int)
    maps, stats = [], []
    for src in sources:
        src = int(src)
        rows = pdf[pdf["srcs"] == src]
        tids = rows["tars"].to_numpy()
        txy = node_feats[tids, :2]
        errors = rows["pred_nmaes"].to_numpy()
        if len(txy) > 0:
            dl = sp_griddata(txy, errors, (gx, gy), method="linear")
            dn = sp_griddata(txy, errors, (gx, gy), method="nearest")
            d2d = np.where(np.isnan(dl), dn, dl)
        else:
            d2d = np.full(gx.shape, np.nan)
        sxy = node_feats[src, :2]
        sc = int(np.searchsorted(all_x, sxy[0]))
        sr = int(np.searchsorted(all_y, sxy[1]))
        me = rows["pred_nmaes"].mean() if len(rows) > 0 else np.nan
        maps.append(d2d)
        stats.append((sr, sc, me))
    return maps, stats

all_maps = {}
shared_vmin = 0
shared_vmax = 0
for label, rinfo in spatial_runs.items():
    m, s = build_nmae_maps(rinfo["preds"], sources_to_plot, node_features, grid_x, grid_y)
    all_maps[label] = (m, s)
    for d2d in m:
        v = np.nanpercentile(d2d, 99)
        if v > shared_vmax:
            shared_vmax = v

MODEL_ORDER = ["GNN", "SparseGT-Random", "SparseGT-Data"]
models_to_plot = [m for m in MODEL_ORDER if m in all_maps]
n_models = len(models_to_plot)

fig = plt.figure(figsize=(7 * n_models, 8), constrained_layout=True)
subfigs = fig.subfigures(1, n_models, wspace=0.04)
if n_models == 1:
    subfigs = [subfigs]

for idx, (subfig, label) in enumerate(zip(subfigs, models_to_plot)):
    dist_maps, source_stats = all_maps[label]
    axes = subfig.subplots(3, 3)
    axes_flat = axes.flatten()
    im = None

    for i, (d2d, (sr, sc, me)) in enumerate(zip(dist_maps, source_stats)):
        ax = axes_flat[i]
        im = ax.imshow(
            d2d, cmap="RdYlBu_r", origin="lower",
            vmin=shared_vmin, vmax=shared_vmax, interpolation="nearest",
        )
        ax.scatter(sc, sr, c="red", s=90, marker="*",
                   edgecolors="white", linewidths=1.5, zorder=5)
        ax.set_title(f"src=({sr},{sc})\nmean_nmae={me:.3f}", fontsize=8)
        ax.set_xticks([])
        ax.set_yticks([])

    for ax in axes_flat[len(sources_to_plot):]:
        ax.axis("off")

    test_nmae = spatial_runs[label]["test_nmae"]
    subfig.suptitle(f"{label}\ntest_nmae={test_nmae:.4f}", fontsize=11)
    subfig.colorbar(im, ax=list(axes_flat), label="|pred - truth| / truth",
                    shrink=0.75, pad=0.02)

fig.suptitle(
    f"Single Source NMAE: cross-model comparison (resolution={SPATIAL_RES})",
    fontsize=14, fontweight="bold",
)
plt.show()
